# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./SpotifyFeatures.csv")
df.head()
# Out:
#    genre        artist_name                        track_name  \
# 0  Movie     Henri Salvador       C'est beau de faire un Show
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper
# 4  Movie       Fabien Nataf                         Ouverture
#
#                  track_id  popularity  acousticness  danceability  \
# 0  0BRjO6ga9RKCKjfDqeFgWV           0         0.611         0.389
# 1  0BjC1NfoEOOusryehmNudP           1         0.246         0.590
# 2  0CoSDzoNIKCRs124s9uTVy           3         0.952         0.663
# 3  0Gc6TVm52BwZD07Ki6tIvf           0         0.703         0.240
# 4  0IuslXpMROHdEPvSl1fTQK           4         0.950         0.331
#
#    duration_ms  energy  instrumentalness key  liveness  loudness   mode  \
# 0        99373   0.910             0.000  C#    0.3460    -1.828  Major
# ...

# %% [markdown]
# # **EyeBall the dataset to see what Insight is Valuable**
# ## - Who most popular artist and song
# ## - Which genre is most popular
# # *Ok lets crack It Now*

# %%
# Subset Column
df.columns
# Out:
# Index(['genre', 'artist_name', 'track_name', 'track_id', 'popularity',
#        'acousticness', 'danceability', 'duration_ms', 'energy',
#        'instrumentalness', 'key', 'liveness', 'loudness', 'mode',
#        'speechiness', 'tempo', 'time_signature', 'valence'],
#       dtype='object')

# %%
spotify = df[['genre','artist_name','track_name','popularity']]
spotify.head()
# Out:
#    genre        artist_name                        track_name  popularity
# 0  Movie     Henri Salvador       C'est beau de faire un Show           0
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)           1
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight           3
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper           0
# 4  Movie       Fabien Nataf                         Ouverture           4

# %% [markdown]
# ## *Clean the dataset*

# %%
## Check the missing or null
spotify.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 232725 entries, 0 to 232724
# Data columns (total 4 columns):
#  #   Column       Non-Null Count   Dtype
# ---  ------       --------------   -----
#  0   genre        232725 non-null  object
#  1   artist_name  232725 non-null  object
#  2   track_name   232725 non-null  object
#  3   popularity   232725 non-null  int64
# dtypes: int64(1), object(3)
# memory usage: 7.1+ MB

# %%
pd.isnull(spotify).sum()
# Out:
# genre          0
# artist_name    0
# track_name     0
# popularity     0
# dtype: int64

# %%
pd.isna(spotify).sum()
# Out:
# genre          0
# artist_name    0
# track_name     0
# popularity     0
# dtype: int64

# %% [markdown]
# # **The data have good quality**
# ## Let's fine the Insight
# ### - *Most popular artist*
# ### - *Most popular Song*
# ### - *Most popular Genre*

# %%
spotify.head()
# Out:
#    genre        artist_name                        track_name  popularity
# 0  Movie     Henri Salvador       C'est beau de faire un Show           0
# 1  Movie  Martin & les fées  Perdu d'avance (par Gad Elmaleh)           1
# 2  Movie    Joseph Williams    Don't Let Me Be Lonely Tonight           3
# 3  Movie     Henri Salvador    Dis-moi Monsieur Gordon Cooper           0
# 4  Movie       Fabien Nataf                         Ouverture           4

# %%
spotify.sort_values("popularity",ascending=False).head(50)
# Out:
#              genre          artist_name  \
# 9027         Dance        Ariana Grande
# 107804         Pop        Ariana Grande
# 86951          Rap          Post Malone
# 107803         Pop          Post Malone
# 107802         Pop        Ariana Grande
# 9026         Dance        Ariana Grande
# 66643      Hip-Hop         Daddy Yankee
# 107909         Pop         Daddy Yankee
# 138918   Reggaeton         Daddy Yankee
# 107829         Pop              Ava Max
# 86953          Rap          Post Malone
# 107875         Pop           Pedro Capó
# 92824        Indie               Halsey
# 107812         Pop           Marshmello
# 9028         Dance               Halsey
# 9037         Dance              Ava Max
# 107806         Pop          Post Malone
# 107810         Pop            Sam Smith
# 107808         Pop               Halsey
# 107851         Pop             DJ Snake
# 107830         Pop            Lady Gaga
# 86952          Rap              J. Cole
# ...
