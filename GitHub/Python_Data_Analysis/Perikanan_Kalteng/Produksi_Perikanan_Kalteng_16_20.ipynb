# %%
import pandas as pd
import numpy as np

# %%
produksi_perikanan_kalteng = pd.read_csv('./Produksi Kabupaten.csv',delimiter=";")

# %%
df =produksi_perikanan_kalteng.copy()

# %%
df.head()
# Out:
#   Column1         Column2  Column3  Column4  Column5  Column6  Column7  \
# 0     No.  Kabupaten_Kota     2016     2017     2018     2019     2020
# 1      1.  Barito Selatan    11131    18823    10449    13661    10508
# 2      2.    Barito Timur     2279     1097     8093     2695     2741
# 3      3.    Barito Utara     5238     8395    11859    11979    12935
# 4      4.      Gunung Mas     3580      261     9138     5634     5326
#
#     Column8
# 0  Rangking
# 1         8
# 2        12
# 3         9
# 4        11

# %% [markdown]
# ### task 1 : Baris 0 isinya adalah kolom tukar dan drop kolom yang sekarang.
# ### task 2 : Drop kolom No. dan kolom rangking.

# %%
df.columns
# Out:
# Index(['Column1', 'Column2', 'Column3', 'Column4', 'Column5', 'Column6',
#        'Column7', 'Column8'],
#       dtype='object')

# %%
df.rename(columns={'Column1':'No', 'Column2':'Kab/Kota', 'Column3':'2016', 
                                           'Column4':'2017', 'Column5':'2018', 'Column6':'2019',
                                           'Column7':'2020', 'Column8':'Drop'},inplace=True)

# %%
df.head()
# Out:
#     No        Kab/Kota   2016   2017   2018   2019   2020      Drop
# 0  No.  Kabupaten_Kota   2016   2017   2018   2019   2020  Rangking
# 1   1.  Barito Selatan  11131  18823  10449  13661  10508         8
# 2   2.    Barito Timur   2279   1097   8093   2695   2741        12
# 3   3.    Barito Utara   5238   8395  11859  11979  12935         9
# 4   4.      Gunung Mas   3580    261   9138   5634   5326        11

# %% [markdown]
# ### task 1 done
# ### Drop kolom drop & No
# ### Drop kolom 0

# %%
df_drop = df.drop(columns=["No","Drop"])

# %%
df_drop.head()
# Out:
#          Kab/Kota   2016   2017   2018   2019   2020
# 0  Kabupaten_Kota   2016   2017   2018   2019   2020
# 1  Barito Selatan  11131  18823  10449  13661  10508
# 2    Barito Timur   2279   1097   8093   2695   2741
# 3    Barito Utara   5238   8395  11859  11979  12935
# 4      Gunung Mas   3580    261   9138   5634   5326

# %%
df_drop.drop ([0],axis=0, inplace=True)

# %%
df_drop.head()
# Out:
#          Kab/Kota   2016   2017   2018   2019   2020
# 1  Barito Selatan  11131  18823  10449  13661  10508
# 2    Barito Timur   2279   1097   8093   2695   2741
# 3    Barito Utara   5238   8395  11859  11979  12935
# 4      Gunung Mas   3580    261   9138   5634   5326
# 5          Kapuas  38628  39397  35515  34928  37062

# %% [markdown]
# ### Good2 Looking good

# %%
df_drop.values
# Out:
# array([['Barito Selatan', 11131, 18823, 10449, 13661, 10508],
#        ['Barito Timur', 2279, 1097, 8093, 2695, 2741],
#        ['Barito Utara', 5238, 8395, 11859, 11979, 12935],
#        ['Gunung Mas', 3580, 261, 9138, 5634, 5326],
#        ['Kapuas', 38628, 39397, 35515, 34928, 37062],
#        ['Katingan', 6152, 3729, 21151, 25250, 24813],
#        ['Kotawaringin Barat', 19947, 21991, 26741, 35268, 42402],
#        ['Kotawaringin Timur', 20206, 32094, 24021, 34739, 38028],
#        ['Lamandau', 2899, 1026, 6786, 2488, 2679],
#        ['Murung Raya', 2310, 265, 4007, 2386, 2729],
#        ['Pulang Pisau', 23058, 23357, 20822, 23417, 24279],
#        ['Seruyan', 34307, 31989, 24847, 29254, 34671],
#        ['Sukamara', 5136, 6344, 9004, 7081, 6907],
#        ['Palangka Raya', 12342, 18774, 18407, 22804, 25916]], dtype=object)

# %%
type(df_drop)
# Out:
# pandas.core.frame.DataFrame

# %%
df_drop.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14 entries, 1 to 14
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Kab/Kota  14 non-null     object
#  1   2016      14 non-null     int64
#  2   2017      14 non-null     int64
#  3   2018      14 non-null     int64
#  4   2019      14 non-null     int64
#  5   2020      14 non-null     int64
# dtypes: int64(5), object(1)
# memory usage: 804.0+ bytes

# %% [markdown]
# ### Looking good
# ### Checkpoint

# %%
produksi_perikanan_kh_16_20 = df_drop.copy()

# %%
produksi_perikanan_kh_16_20
# Out:
#               Kab/Kota   2016   2017   2018   2019   2020
# 1       Barito Selatan  11131  18823  10449  13661  10508
# 2         Barito Timur   2279   1097   8093   2695   2741
# 3         Barito Utara   5238   8395  11859  11979  12935
# 4           Gunung Mas   3580    261   9138   5634   5326
# 5               Kapuas  38628  39397  35515  34928  37062
# 6             Katingan   6152   3729  21151  25250  24813
# 7   Kotawaringin Barat  19947  21991  26741  35268  42402
# 8   Kotawaringin Timur  20206  32094  24021  34739  38028
# 9             Lamandau   2899   1026   6786   2488   2679
# 10         Murung Raya   2310    265   4007   2386   2729
# 11        Pulang Pisau  23058  23357  20822  23417  24279
# 12             Seruyan  34307  31989  24847  29254  34671
# 13            Sukamara   5136   6344   9004   7081   6907
# 14       Palangka Raya  12342  18774  18407  22804  25916

# %% [markdown]
# ### Import ke CSV lagi

# %%
produksi_perikanan_kh_16_20.to_csv("Produksi Perikanan Kalteng 2016-2020 Clear.csv",index=False)

# %% [markdown]
# # File Baru Perikanan Budidaya

# %%
df_raw = pd.read_csv('./Perikanan Budidaya 2016 -2020.csv',delimiter=";")

# %%
df_raw
# Out:
#    Produksi Perikanan Budidaya Per Tahun          Unnamed: 1 Unnamed: 2  \
# 0                                    No.      Kabupaten/Kota       2016
# 1                                     1.      Barito Selatan   8.583,61
# 2                                     2.        Barito Timur   1.169,00
# 3                                     3.        Barito Utara   4.350,40
# 4                                     4.          Gunung Mas   3.227,15
# 5                                     5.              Kapuas  14.562,03
# 6                                     6.            Katingan   3.732,36
# 7                                     7.  Kotawaringin Barat   5.154,02
# 8                                     8.  Kotawaringin Timur   5.517,57
# 9                                     9.            Lamandau   1.779,68
# 10                                   10.         Murung Raya   2.102,87
# 11                                   11.        Pulang Pisau   3.943,52
# ...

# %% [markdown]
# ### task : Kolom salah
# ### baris 0 adalam kolom
# ### drop No & kolom 6
# ### drop baris total

# %%
df_raw.columns.values
# Out:
# array(['Produksi Perikanan Budidaya Per Tahun', 'Unnamed: 1',
#        'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5',
#        'Unnamed: 6', 'Unnamed: 7'], dtype=object)

# %%
df_raw_drop = df_raw.drop (columns=['Produksi Perikanan Budidaya Per Tahun','Unnamed: 7'])

# %%
df_raw_drop.head()
# Out:
#        Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6
# 0  Kabupaten/Kota       2016       2017       2018       2019       2020
# 1  Barito Selatan   8.583,61   9.436,46  10.114,07  11.085,76   7.898,55
# 2    Barito Timur   1.169,00   1.643,24   1.436,87   1.682,25   1.438,33
# 3    Barito Utara   4.350,40   6.598,45   5.934,60   5.964,12   8.228,92
# 4      Gunung Mas   3.227,15   4.888,98   6.014,98   5.265,50   5.094,55

# %%
df_raw_drop.rename(columns={'Unnamed: 1':'Kab/kota','Unnamed: 2':'2016', 'Unnamed: 3':'2017', 'Unnamed: 4':'2018', 'Unnamed: 5':'2019',
       'Unnamed: 6':'2020'},inplace=True)

# %%
df_raw_drop.head()
# Out:
#          Kab/kota      2016      2017       2018       2019      2020
# 0  Kabupaten/Kota      2016      2017       2018       2019      2020
# 1  Barito Selatan  8.583,61  9.436,46  10.114,07  11.085,76  7.898,55
# 2    Barito Timur  1.169,00  1.643,24   1.436,87   1.682,25  1.438,33
# 3    Barito Utara  4.350,40  6.598,45   5.934,60   5.964,12  8.228,92
# 4      Gunung Mas  3.227,15  4.888,98   6.014,98   5.265,50  5.094,55

# %%
df_d = df_raw_drop.copy()

# %%
df_d.drop ([0],axis=0,inplace=True)

# %%
df_d.head()
# Out:
#          Kab/kota       2016       2017       2018       2019       2020
# 1  Barito Selatan   8.583,61   9.436,46  10.114,07  11.085,76   7.898,55
# 2    Barito Timur   1.169,00   1.643,24   1.436,87   1.682,25   1.438,33
# 3    Barito Utara   4.350,40   6.598,45   5.934,60   5.964,12   8.228,92
# 4      Gunung Mas   3.227,15   4.888,98   6.014,98   5.265,50   5.094,55
# 5          Kapuas  14.562,03  18.153,40  15.893,36  18.124,06  17.132,07

# %% [markdown]
# ## Good2 its clean
# ## Save the file

# %%
df_d.to_csv("Perikana Budidaya 2016 - 2020 Clear.csv",index=False)

# %% [markdown]
# ## File Baru Perikanan Tangkap 2016 - 2020

# %%
ikan_tangkap = pd.read_csv('./Perikanan Tangkap 2016-2020.csv',delimiter=';')

# %%
ikan_tangkap = ikan_tangkap.copy()

# %%
ikan_tangkap.head()
# Out:
#   Produksi Perikanan Tangkap Per Tahun          Unnamed: 1 Unnamed: 2  \
# 0                                  No.            Kab/Kota       2016
# 1                                   1.  Kotawaringin Barat  14.792,70
# 2                                   2.  Kotawaringin Timur  14.688,80
# 3                                   3.              Kapuas  24.065,88
# 4                                   4.      Barito Selatan   2.547,80
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7
# 0       2017       2018       2019       2020   Rangking
# 1  14.470,10  18.301,17  26.400,86  32.113,10          1
# 2  26.107,93  17.444,47  28.106,19  24.729,14          2
# 3  17.253,00  19.622,05  16.802,65  19.930,06          4
# 4   6.482,00     334,54   2.575,12   2.609,27         10

# %%
ikan_tangkap_drop = ikan_tangkap.drop(columns=['Produksi Perikanan Tangkap Per Tahun','Unnamed: 7'])

# %%
ikan_tangkap_drop.head()
# Out:
#            Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6
# 0            Kab/Kota       2016       2017       2018       2019       2020
# 1  Kotawaringin Barat  14.792,70  14.470,10  18.301,17  26.400,86  32.113,10
# 2  Kotawaringin Timur  14.688,80  26.107,93  17.444,47  28.106,19  24.729,14
# 3              Kapuas  24.065,88  17.253,00  19.622,05  16.802,65  19.930,06
# 4      Barito Selatan   2.547,80   6.482,00     334,54   2.575,12   2.609,27

# %%
ikan_tangkap_drop.columns.values
# Out:
# array(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6'], dtype=object)

# %%
ikan_tangkap_drop.values[0]
# Out:
# array(['Kab/Kota', '2016', '2017', '2018', '2019', '2020'], dtype=object)

# %%
ikan_tangkap_drop.rename(columns={'Unnamed: 1':'Kab/Kota', 'Unnamed: 2':'2016', 'Unnamed: 3':'2017', 'Unnamed: 4':'2018',
       'Unnamed: 5':'2019', 'Unnamed: 6':'2020'},inplace=True)

# %%
ikan_tangkap_drop.head()
# Out:
#              Kab/Kota       2016       2017       2018       2019       2020
# 0            Kab/Kota       2016       2017       2018       2019       2020
# 1  Kotawaringin Barat  14.792,70  14.470,10  18.301,17  26.400,86  32.113,10
# 2  Kotawaringin Timur  14.688,80  26.107,93  17.444,47  28.106,19  24.729,14
# 3              Kapuas  24.065,88  17.253,00  19.622,05  16.802,65  19.930,06
# 4      Barito Selatan   2.547,80   6.482,00     334,54   2.575,12   2.609,27

# %%
ikan_tangkap_drop.drop([0],axis=0,inplace=True)
ikan_tangkap_drop.head()
# Out:
#              Kab/Kota       2016       2017       2018       2019       2020
# 1  Kotawaringin Barat  14.792,70  14.470,10  18.301,17  26.400,86  32.113,10
# 2  Kotawaringin Timur  14.688,80  26.107,93  17.444,47  28.106,19  24.729,14
# 3              Kapuas  24.065,88  17.253,00  19.622,05  16.802,65  19.930,06
# 4      Barito Selatan   2.547,80   6.482,00     334,54   2.575,12   2.609,27
# 5        Barito Timur   1.110,30   1.096,80   6.656,32   1.012,65   1.302,92

# %%
ikan_tangkap_drop.to_csv("Produksi Ikan Tangkap 2016 - 2020 Clear.csv",index=False)

# %% [markdown]
# ## File baru Nilai Export & Volume Export

# %%
nilai_eksport = pd.read_csv("./Nilai Ekspor 2016-2020.csv",delimiter=";")
volume_eksport = pd.read_csv("./Volume ekspor (Ekor).csv",delimiter=";")

# %%
nilai_eksport.head()
# Out:
#   Nilai Ekspor (Rp.000)  Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4  \
# 0                   No.  Jenis Ikan        NaN        NaN        NaN
# 1                   NaN         NaN       2016       2017       2018
# 2                    1.  Baung Hias    157.280     18.000          0
# 3                    2.  kalochroma     22.500          0          0
# 4                    3.  Kulliloach    269.000        300          0
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7
# 0        NaN        NaN      Total
# 1       2019       2020        NaN
# 2          0      2.760    178.040
# 3          0          0     22.500
# 4          0    223.000    492.300

# %%
nilai_eksport_drop = nilai_eksport.drop (columns=['Nilai Ekspor (Rp.000)','Unnamed: 7'])
nilai_eksport_drop.head()
# Out:
#    Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6
# 0  Jenis Ikan        NaN        NaN        NaN        NaN        NaN
# 1         NaN       2016       2017       2018       2019       2020
# 2  Baung Hias    157.280     18.000          0          0      2.760
# 3  kalochroma     22.500          0          0          0          0
# 4  Kulliloach    269.000        300          0          0    223.000

# %%
nilai_eksport_drop.columns.values
# Out:
# array(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6'], dtype=object)

# %%
nilai_eksport = nilai_eksport_drop.copy()

# %%
nilai_eksport.rename(columns={'Unnamed: 1':'Jenis Ikan', 'Unnamed: 2':'2016', 'Unnamed: 3':'2017', 'Unnamed: 4':'2018',
       'Unnamed: 5':'2019', 'Unnamed: 6':'2020'},inplace=True)
nilai_eksport.head()
# Out:
#    Jenis Ikan     2016    2017  2018  2019     2020
# 0  Jenis Ikan      NaN     NaN   NaN   NaN      NaN
# 1         NaN     2016    2017  2018  2019     2020
# 2  Baung Hias  157.280  18.000     0     0    2.760
# 3  kalochroma   22.500       0     0     0        0
# 4  Kulliloach  269.000     300     0     0  223.000

# %%
nilai_eksport.drop([0,1],axis=0,inplace=True)

# %%
nilai_eksport
# Out:
#         Jenis Ikan       2016       2017       2018       2019       2020
# 2       Baung Hias    157.280     18.000          0          0      2.760
# 3       kalochroma     22.500          0          0          0          0
# 4       Kulliloach    269.000        300          0          0    223.000
# 5           Rhombo     11.200      2.520     16.000     27.500          0
# 6          Seluang     69.000     26.950     14.500     10.500    152.400
# 7            Silli      3.200     13.515          0        100      4.550
# 8   Gurame Cokelat     52.875    123.000     33.750    164.250      7.500
# 9            Botia  2.021.875  2.668.750  4.166.250  5.040.000  2.715.750
# 10       Kerandang     21.385        375          0         70          0
# 11  Julung- julung     51.650          0          0          0     48.900
# 12      Tiger Fish        500        240          0      1.500        180
# 13        Bagarius        225          0          0          0          0
# ...

# %%
nilai_eksport.drop([29],axis=0,inplace=True)

# %%
nilai_eksport.tail()
# Out:
#      Jenis Ikan    2016   2017 2018 2019    2020
# 24   Flying Fox       0      0    0    0  25.500
# 25  Botia Hijau       0      0    0    0  35.000
# 26        Gabus       0      0    0    0  27.015
# 27  Kepala Kuda  55.000  4.500    0    0       0
# 28       Peyang       0      0    0    0  29.250

# %%
nilai_eksport.to_csv("Nilai Ekspor Perikanan 2016 - 2020 Clear.csv",index=False)

# %% [markdown]
# ## File Baru Volume Eksport

# %%
volume_eksport.head()
# Out:
#   Volume ekspor (Ekor)  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0                   No   Komoditas    2016.000      2017.0      2018.0
# 1                    1  Baung Hias      10.552         1.2         0.0
# 2                    2  kalochroma       1.500         0.0         0.0
# 3                    3  Kulliloach      24.900        20.0         0.0
# 4                    4      Rhombo       1.120       252.0      1600.0
#
#    Unnamed: 5  Unnamed: 6 Unnamed: 7
# 0     2019.00      2020.0      Total
# 1        0.00       184.0     11.936
# 2        0.00         0.0      1.500
# 3        0.00        22.3     47.220
# 4        2.75         0.0      5.722

# %%
volume_eksport = volume_eksport.drop(columns=["Volume ekspor (Ekor)","Unnamed: 7"])

# %%
volume_eksport.head()
# Out:
#    Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6
# 0   Komoditas    2016.000      2017.0      2018.0     2019.00      2020.0
# 1  Baung Hias      10.552         1.2         0.0        0.00       184.0
# 2  kalochroma       1.500         0.0         0.0        0.00         0.0
# 3  Kulliloach      24.900        20.0         0.0        0.00        22.3
# 4      Rhombo       1.120       252.0      1600.0        2.75         0.0

# %%
volume_eksport.tail()
# Out:
#      Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6
# 24   Flying Fox         0.0         0.0         0.0         0.0        1.70
# 25  Botia Hijau         0.0         0.0         0.0         0.0        1.40
# 26        Gabus         0.0         0.0         0.0         0.0      541.00
# 27  Kepala Kuda         1.1       300.0         NaN         NaN         NaN
# 28       Peyang         0.0         0.0         0.0         0.0        1.95

# %%
volume_eksport.columns.values
# Out:
# array(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6'], dtype=object)

# %%
volume_eksport = volume_eksport.rename(columns={'Unnamed: 1':'Komoditas','Unnamed: 2':'2016',
                                                'Unnamed: 3':'2017', 'Unnamed: 4':'2018',
                                                'Unnamed: 5':'2019', 'Unnamed: 6':'2020'})

# %%
volume_eksport.head()
# Out:
#     Komoditas      2016    2017    2018     2019    2020
# 0   Komoditas  2016.000  2017.0  2018.0  2019.00  2020.0
# 1  Baung Hias    10.552     1.2     0.0     0.00   184.0
# 2  kalochroma     1.500     0.0     0.0     0.00     0.0
# 3  Kulliloach    24.900    20.0     0.0     0.00    22.3
# 4      Rhombo     1.120   252.0  1600.0     2.75     0.0

# %%
volume_eksport = volume_eksport.drop([0],axis=0)

# %%
volume_eksport.head()
# Out:
#     Komoditas    2016    2017    2018  2019    2020
# 1  Baung Hias  10.552    1.20     0.0  0.00  184.00
# 2  kalochroma   1.500    0.00     0.0  0.00    0.00
# 3  Kulliloach  24.900   20.00     0.0  0.00   22.30
# 4      Rhombo   1.120  252.00  1600.0  2.75    0.00
# 5     Seluang   5.050    2.08  1450.0  1.05   15.14

# %%
volume_eksport.to_csv("Volume Ekspor Perikanan 2016 - 2020 Clear.csv",index=False)

# %% [markdown]
# ## File Baru Produksi Perikanan

# %%
produk_olahan = pd.read_csv('./Produk Olahan Perikanan 2016-2020.csv',delimiter=';')

# %%
produk_olahan_df = produk_olahan.copy()
produk_olahan_df.head()
# Out:
#   Produksi Produk Olahan Perikanan Tahun       Unnamed: 1 Unnamed: 2  \
# 0                                    No.  Kabupaten/ Kota       2016
# 1                                     1.   Barito Selatan     531,01
# 2                                     2.     Barito Timur      39,25
# 3                                     3.     Barito Utara       6,85
# 4                                     4.       Gunung Mas      17,63
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7
# 0       2017       2018       2019       2020   Rangking
# 1     203,78      208,5     223,62      86,68         10
# 2      10,68       37,1      49,29      55,56         11
# 3      25,67     165,48     305,66      30,97         13
# 4      35,56      67,63     112,94      50,18         12

# %%
 produk_olahan_drop = produk_olahan_df.drop(columns=["Produksi Produk Olahan Perikanan Tahun","Unnamed: 7"])

# %%
produk_olahan_drop.head()
# Out:
#         Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6
# 0  Kabupaten/ Kota       2016       2017       2018       2019       2020
# 1   Barito Selatan     531,01     203,78      208,5     223,62      86,68
# 2     Barito Timur      39,25      10,68       37,1      49,29      55,56
# 3     Barito Utara       6,85      25,67     165,48     305,66      30,97
# 4       Gunung Mas      17,63      35,56      67,63     112,94      50,18

# %%
produk_olahan_drop.columns.values
# Out:
# array(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4',
#        'Unnamed: 5', 'Unnamed: 6'], dtype=object)

# %%
produk=produk_olahan_drop.rename(columns= {'Unnamed: 1':'Kab/Kota', 'Unnamed: 2':'2016', 'Unnamed: 3':'2017', 'Unnamed: 4':'2018',
                                           'Unnamed: 5':'2019', 'Unnamed: 6':'2020'})
                                           
produk.drop([0,15],axis=0,inplace=True)
produk.head()
# Out:
#          Kab/Kota      2016      2017      2018      2019      2020
# 1  Barito Selatan    531,01    203,78     208,5    223,62     86,68
# 2    Barito Timur     39,25     10,68      37,1     49,29     55,56
# 3    Barito Utara      6,85     25,67    165,48    305,66     30,97
# 4      Gunung Mas     17,63     35,56     67,63    112,94     50,18
# 5          Kapuas  2.239,31  1.770,30  1.974,84  2.237,64  2.249,68

# %%
produk.to_csv("Produk Olahan Perikanan 2016 - 2020 Clear.csv",index=False)
